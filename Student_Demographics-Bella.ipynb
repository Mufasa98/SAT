# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
# Import API key
from doe_api import doe_key

# %%
#dependent/independent
#first gen/non-first gen
url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json'
params4 = {
    'api_key': doe_key,
    'per_page': 250,
    'fields': "id,location.lon,location.lat,latest.school.name,"+
    
    #students financially independent/dependent
    "latest.student.share_independent_lowincome.0_30000,latest.student.share_independent_students,latest.student.share_dependent_lowincome.0_300000,"+
    "latest.student.share_lowincome.0_30000,"+
    
    #first gen
    "latest.student.share_firstgeneration,latest.student.share_firstgeneration_parents.somecollege,"+
    "latest.student.share_firstgeneration_parents.middleschool,latest.student.share_firstgeneration_parents.highschool,"+
    
    #first gen tranfered to 4 year
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs,latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs,"+
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs,latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs,"+
    "latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs,"+
    
    #via census data demographics (population of students by zipcode)
    "latest.student.demographics.share_bachelors_degree_age25.home_ZIP,latest.student.demographics.share_born_US.home_ZIP,"+
    "latest.student.demographics.share_white.home_ZIP,latest.student.demographics.share_hispanic.home_ZIP,"+
    "latest.student.demographics.share_black.home_ZIP,latest.student.demographics.share_asian.home_ZIP,"+
    "latest.student.demographics.share_professional_degree_age25.home_ZIP,"+
    
    #independent
    #general completion
    "latest.completion.title_iv.independ.completed_by.2yrs,latest.completion.title_iv.independ.completed_by.3yrs,"+
    "latest.completion.title_iv.independ.completed_by.4yrs,latest.completion.title_iv.independ.completed_by.6yrs,"+
    "latest.completion.title_iv.independ.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.independ.withdrawn_by.2yrs,latest.completion.title_iv.independ.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.independ.withdrawn_by.4yrs,latest.completion.title_iv.independ.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.independ.withdrawn_by.8yrs,"+
    
    #dependent
    #general completion
    "latest.completion.title_iv.depend.completed_by.2yrs,latest.completion.title_iv.depend.completed_by.3yrs,"+
    "latest.completion.title_iv.depend.completed_by.4yrs,latest.completion.title_iv.depend.completed_by.6yrs,"+
    "latest.completion.title_iv.depend.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.depend.withdrawn_by.2yrs,latest.completion.title_iv.depend.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.depend.withdrawn_by.4yrs,latest.completion.title_iv.depend.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.depend.withdrawn_by.8yrs,"+
    
    #non-first gen
    #general completion
    "latest.completion.title_iv.not_first_gen.completed_by.2yrs,latest.completion.title_iv.not_first_gen.completed_by.3yrs,"+
    "latest.completion.title_iv.not_first_gen.completed_by.4yrs,latest.completion.title_iv.not_first_gen.completed_by.6yrs,"+
    "latest.completion.title_iv.not_first_gen.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs,latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs,latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs,"+
    
    #first gen
    #general completion
    "latest.completion.title_iv.first_gen.completed_by.2yrs,latest.completion.title_iv.first_gen.completed_by.3yrs,"+
    "latest.completion.title_iv.first_gen.completed_by.4yrs,latest.completion.title_iv.first_gen.completed_by.6yrs,"+
    "latest.completion.title_iv.first_gen.completed_by.8yrs,"+
    #general withdrew
    "latest.completion.title_iv.first_gen.withdrawn_by.2yrs,latest.completion.title_iv.first_gen.withdrawn_by.3yrs,"+
    "latest.completion.title_iv.first_gen.withdrawn_by.4yrs,latest.completion.title_iv.first_gen.withdrawn_by.6yrs,"+
    "latest.completion.title_iv.first_gen.withdrawn_by.8yrs,"
    "page = 0"
}

# %%
# Initialize an empty list to store the data
dependency_data = []
#starting page is 0
params4['page'] = 0

#loop that will loop through the page until we reach page 6
while params4['page'] < 7:
    #api call
    response = requests.get(url, params=params4).json()
    next_page_results = response.get("results", [])
    dependency_data.extend(next_page_results)
    #to go to the next page of results
    params4['page'] += 1

# %%
dependency_df = pd.DataFrame(dependency_data)
dependency_df.columns
# Out:
# Index(['latest.school.name',
#        'latest.student.share_independent_lowincome.0_30000',
#        'latest.student.share_independent_students',
#        'latest.student.share_dependent_lowincome.0_300000',
#        'latest.student.share_lowincome.0_30000',
#        'latest.student.share_firstgeneration',
#        'latest.student.share_firstgeneration_parents.somecollege',
#        'latest.student.share_firstgeneration_parents.middleschool',
#        'latest.student.share_firstgeneration_parents.highschool',
#        'latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs',
#        'latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs',
#        'latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs',
#        'latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs',
#        'latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs',
#        'latest.student.demographics.share_bachelors_degree_age25.home_ZIP',
#        'latest.student.demographics.share_born_US.home_ZIP',
#        'latest.student.demographics.share_white.home_ZIP',
#        'latest.student.demographics.share_hispanic.home_ZIP',
#        'latest.student.demographics.share_black.home_ZIP',
#        'latest.student.demographics.share_asian.home_ZIP',
#        'latest.student.demographics.share_professional_degree_age25.home_ZIP',
#        'latest.completion.title_iv.independ.completed_by.2yrs',
#        'latest.completion.title_iv.independ.completed_by.3yrs',
#        'latest.completion.title_iv.independ.completed_by.4yrs',
#        'latest.completion.title_iv.independ.completed_by.6yrs',
#        'latest.completion.title_iv.independ.completed_by.8yrs',
#        'latest.completion.title_iv.independ.withdrawn_by.2yrs',
#        'latest.completion.title_iv.independ.withdrawn_by.3yrs',
#        'latest.completion.title_iv.independ.withdrawn_by.4yrs',
#        'latest.completion.title_iv.independ.withdrawn_by.6yrs',
#        'latest.completion.title_iv.independ.withdrawn_by.8yrs',
#        'latest.completion.title_iv.depend.completed_by.2yrs',
#        'latest.completion.title_iv.depend.completed_by.3yrs',
#        'latest.completion.title_iv.depend.completed_by.4yrs',
#        'latest.completion.title_iv.depend.completed_by.6yrs',
#        'latest.completion.title_iv.depend.completed_by.8yrs',
#        'latest.completion.title_iv.depend.withdrawn_by.2yrs',
#        'latest.completion.title_iv.depend.withdrawn_by.3yrs',
#        'latest.completion.title_iv.depend.withdrawn_by.4yrs',
#        'latest.completion.title_iv.depend.withdrawn_by.6yrs',
#        'latest.completion.title_iv.depend.withdrawn_by.8yrs',
#        'latest.completion.title_iv.not_first_gen.completed_by.2yrs',
#        'latest.completion.title_iv.not_first_gen.completed_by.3yrs',
#        'latest.completion.title_iv.not_first_gen.completed_by.4yrs',
#        'latest.completion.title_iv.not_first_gen.completed_by.6yrs',
#        'latest.completion.title_iv.not_first_gen.completed_by.8yrs',
#        'latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs',
#        'latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs',
#        'latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs',
#        'latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs',
#        'latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs',
#        'latest.completion.title_iv.first_gen.completed_by.2yrs',
#        'latest.completion.title_iv.first_gen.completed_by.3yrs',
#        'latest.completion.title_iv.first_gen.completed_by.4yrs',
#        'latest.completion.title_iv.first_gen.completed_by.6yrs',
#        'latest.completion.title_iv.first_gen.completed_by.8yrs',
#        'latest.completion.title_iv.first_gen.withdrawn_by.2yrs',
#        'latest.completion.title_iv.first_gen.withdrawn_by.3yrs',
#        'latest.completion.title_iv.first_gen.withdrawn_by.4yrs',
#        'latest.completion.title_iv.first_gen.withdrawn_by.6yrs',
#        'latest.completion.title_iv.first_gen.withdrawn_by.8yrs', 'id',
#        'location.lat', 'location.lon'],
#       dtype='object')

# %%
#dropping unneccessary columns 
#fillna replaces null values with a specified value
dependency_df = pd.DataFrame(dependency_data)
dependency_df = dependency_df.fillna(0)
dependency_df = dependency_df.drop(columns = [])

# %%
#renaming columns 
dependency_clean = dependency_df.rename(columns={
    'latest.school.name': 'School Name',
    'latest.student.share_firstgeneration':'% First Generation Students',
    'latest.student.share_firstgeneration_parents.somecollege':'% First Gen, Parents w/College',
    'latest.student.share_firstgeneration_parents.middleschool':'% First Gen, Parents w/MiddleSchool',
    'latest.student.share_firstgeneration_parents.highschool': '% First Gen, Parents w/HighSchool',
    'latest.student.share_dependent_lowincome.0_300000': '% DepStudents, LowIncome $0-$30,000',
    'latest.student.share_independent_lowincome.0_30000': '% IndepStudents, LowIncome $0-$30,000', 
    'latest.student.share_independent_students': '% Independent Students',
    'latest.student.share_lowincome.0_30000':'% aided students family income $0-$30,000',
    'latest.completion.title_iv.first_gen.transf_completed_4yr_by.2yrs': '% FirstGenStudents, Completed 2 Years',
    'latest.completion.title_iv.first_gen.transf_completed_4yr_by.3yrs': '% FirstGenStudents, Completed 3 Years',
    'latest.completion.title_iv.first_gen.transf_completed_4yr_by.4yrs':'% FirstGenStudents, Completed 4 Years',
    'latest.completion.title_iv.first_gen.transf_completed_4yr_by.6yrs': '% FirstGenStudents, Completed 6 Years',
    'latest.completion.title_iv.first_gen.transf_completed_4yr_by.8yrs': '% FirstGenStudents, Completed 8 Years',
    'latest.student.demographics.share_bachelors_degree_age25.home_ZIP': '% Students W/Bachelors Degree at 25 Years Old',
    'latest.student.demographics.share_born_US.home_ZIP': '% Students Born Within the U.S.',
    'latest.student.demographics.share_white.home_ZIP': '% Population of White Students by ZIP Code',
    'latest.student.demographics.share_hispanic.home_ZIP': '% Population of Hispanic Students by ZIP Code',
    'latest.student.demographics.share_black.home_ZIP': '% Population of Black Students by ZIP Code',
    'latest.student.demographics.share_asian.home_ZIP': '% Population of Asian Students by ZIP Code',
    'latest.student.demographics.share_professional_degree_age25.home_ZIP': '% Students W/Professional Deg at 25YrsbyZIP',
    'latest.completion.title_iv.independ.completed_by.2yrs': '% IndepStudents Completed 2 Years',
    'latest.completion.title_iv.independ.completed_by.3yrs': '% IndepStudents Completed 3 Years',
    'latest.completion.title_iv.independ.completed_by.4yrs':'% IndepStudents Completed 4 Years',
    'latest.completion.title_iv.independ.completed_by.6yrs':'% IndepStudents Completed 6 Years',
    'latest.completion.title_iv.independ.completed_by.8yrs':'% IndepStudents Completed 8 Years',
    'latest.completion.title_iv.independ.withdrawn_by.2yrs':'% IndepStudents Withdrawn 2 Years',
    'latest.completion.title_iv.independ.withdrawn_by.3yrs':'% IndepStudents Withdrawn 3 Years',
    'latest.completion.title_iv.independ.withdrawn_by.4yrs':'% IndepStudents Withdrawn 4 Years',
    'latest.completion.title_iv.independ.withdrawn_by.6yrs':'% IndepStudents Withdrawn 6 Years',
    'latest.completion.title_iv.independ.withdrawn_by.8yrs':'% IndepStudents Withdrawn 8 Years',
    'latest.completion.title_iv.depend.completed_by.2yrs':'% DepStudents Completed 2 Years',
    'latest.completion.title_iv.depend.completed_by.3yrs':'% DepStudents Completed 3 Years',
    'latest.completion.title_iv.depend.completed_by.4yrs':'% DepStudents Completed 4 Years',
    'latest.completion.title_iv.depend.completed_by.6yrs':'% DepStudents Completed 6 Years',
    'latest.completion.title_iv.depend.completed_by.8yrs':'% DepStudents Completed 8 Years',
    'latest.completion.title_iv.depend.withdrawn_by.2yrs':'% DepStudents Withdrawn 2 Years',
    'latest.completion.title_iv.depend.withdrawn_by.3yrs':'% DepStudents Withdrawn 3 Years',
    'latest.completion.title_iv.depend.withdrawn_by.4yrs':'% DepStudents, Withdrawn 4 Years',
    'latest.completion.title_iv.depend.withdrawn_by.6yrs':'% DepStudents, Withdrawn 6 Years',
    'latest.completion.title_iv.depend.withdrawn_by.8yrs':'% DepStudents, Withdrawn 8 Years',
    'latest.completion.title_iv.not_first_gen.completed_by.2yrs':'% NonFirstGenStudents Completed 2 Years',
    'latest.completion.title_iv.not_first_gen.completed_by.3yrs':'% NonFirstGenStudents Completed 3 Years',
    'latest.completion.title_iv.not_first_gen.completed_by.4yrs':'% NonFirstGenStudents Completed 4 Years',
    'latest.completion.title_iv.not_first_gen.completed_by.6yrs':'% NonFirstGenStudents Completed 6 Years',
    'latest.completion.title_iv.not_first_gen.completed_by.8yrs':'% NonFirstGenStudents Completed 8 Years',
    'latest.completion.title_iv.not_first_gen.withdrawn_by.2yrs':'% NonFirstGenStudents Withdrawn 2 Years',
    'latest.completion.title_iv.not_first_gen.withdrawn_by.3yrs':'% NonFirstGenStudents Withdrawn 3 Years',
    'latest.completion.title_iv.not_first_gen.withdrawn_by.4yrs':'% NonFirstGenStudents Withdrawn 4 Years',
    'latest.completion.title_iv.not_first_gen.withdrawn_by.6yrs':'% NonFirstGenStudents Withdrawn 6 Years',
    'latest.completion.title_iv.not_first_gen.withdrawn_by.8yrs':'% NonFirstGenStudents Withdrawn 8 Years',
    'latest.completion.title_iv.first_gen.completed_by.2yrs': '% FirstGenStudents Completed 2 Years',
    'latest.completion.title_iv.first_gen.completed_by.3yrs': '% FirstGenStudents Completed 3 Years',
    'latest.completion.title_iv.first_gen.completed_by.4yrs': '% FirstGenStudents Completed 4 Years',
    'latest.completion.title_iv.first_gen.completed_by.6yrs': '% FirstGenStudents Completed 6 Years',
    'latest.completion.title_iv.first_gen.completed_by.8yrs': '% FirstGenStudents Completed 8 Years',
    'latest.completion.title_iv.first_gen.withdrawn_by.2yrs': '% FirstGenStudents Withdrawn 2 Years',
    'latest.completion.title_iv.first_gen.withdrawn_by.3yrs': '% FirstGenStudents Withdrawn 3 Years',
    'latest.completion.title_iv.first_gen.withdrawn_by.4yrs': '% FirstGenStudents Withdrawn 4 Years',
    'latest.completion.title_iv.first_gen.withdrawn_by.6yrs': '% FirstGenStudents Withdrawn 6 Years',
    'latest.completion.title_iv.first_gen.withdrawn_by.8yrs': '% FirstGenStudents Withdrawn 8 Years', 
    'location.lat': 'Latitude',
    'location.lon': 'Longitutde'
})

# %%
#forloop to change from decimal to percentage
for i in dependency_clean.columns[1:]:
    dependency_clean[i] = dependency_clean[i] * 100

# %%
dependency_clean
# Out:
#                                            School Name  \
# 0                             Alabama A & M University
# 1                  University of Alabama at Birmingham
# 2                                   Amridge University
# 3                  University of Alabama in Huntsville
# 4                             Alabama State University
# ..                                                 ...
# 695  Robert Morgan Educational Center and Technical...
# 696                                    Rollins College
# 697                      First Coast Technical College
# 698                               Saint Leo University
# 699                              St Petersburg College
#
#      % IndepStudents, LowIncome $0-$30,000  % Independent Students  \
# 0                                90.158730                9.887006
# 1                                59.420290               32.140861
# 2                                 0.000000               89.527027
# 3                                68.885191               25.156969
# 4                                92.193309               10.742812
# ..                                     ...                     ...
# 695                              88.953488               46.361186
# 696                              64.779874               19.875000
# 697                              84.879725               67.674419
# 698                              67.374980               78.868448
# 699                              71.350658               54.236993
#
#      % DepStudents, LowIncome $0-$30,000  \
# 0                              56.913967
# 1                              34.870950
# 2                               0.000000
# 3                              26.901566
# 4                              57.762864
# ..                                   ...
# 695                            63.316583
# 696                            28.705148
# 697                            64.748201
# 698                            43.530113
# 699                            49.087452
#
#      % aided students family income $0-$30,000  % First Generation Students  \
# 0                                    60.200879                    36.582809
# 1                                    42.761319                    34.122367
# 2                                    77.364865                    51.250000
# 3                                    37.463374                    31.013216
# 4                                    61.461661                    34.343434
# ..                                         ...                          ...
# 695                                  75.202156                    51.557093
# 696                                  35.875000                    23.753281
# 697                                  78.372093                    50.546448
# 698                                  62.336190                    49.104320
# 699                                  61.162346                    44.426396
#
#      % First Gen, Parents w/College  % First Gen, Parents w/MiddleSchool  \
# 0                         63.417191                             1.642208
# 1                         65.877633                             2.226680
# 2                         48.750000                             5.000000
# 3                         68.986784                             1.982379
# 4                         65.656566                             1.882461
# ..                              ...                                  ...
# 695                       48.442907                             5.190311
# 696                       76.246719                             0.000000
# 697                       49.453552                             5.191257
# 698                       50.895680                             4.350444
# 699                       55.573604                             3.644670
#
#      % First Gen, Parents w/HighSchool  % FirstGenStudents, Completed 2 Years  \
# 0                            34.940601                               0.000000
# 1                            31.895687                               3.251318
# 2                            46.250000                               0.000000
# 3                            29.030837                               0.000000
# 4                            32.460973                               0.000000
# ..                                 ...                                    ...
# 695                          46.366782                               0.000000
# 696                           0.000000                               0.000000
# 697                          45.355191                               0.000000
# 698                          44.753876                               0.000000
# 699                          40.781726                               1.669675
#
#      ...  % FirstGenStudents Completed 6 Years  \
# 0    ...                             29.463415
# 1    ...                             51.470588
# 2    ...                              0.000000
# 3    ...                             45.394737
# 4    ...                             30.160952
# ..   ...                                   ...
# 695  ...                             27.586207
# 696  ...                             67.729084
# 697  ...                             54.752852
# 698  ...                             36.671303
# 699  ...                             27.599727
#
#      % FirstGenStudents Completed 8 Years  \
# 0                               28.538550
# 1                               51.953770
# 2                                0.000000
# 3                               46.867168
# 4                               26.888218
# ..                                    ...
# 695                             29.597701
# 696                             65.460526
# 697                             44.705882
# 698                             41.816367
# 699                             25.872943
#
#      % FirstGenStudents Withdrawn 2 Years  \
# 0                               35.826772
# 1                               21.485062
# 2                                0.000000
# 3                               23.888314
# 4                               34.318182
# ..                                    ...
# 695                             44.805195
# 696                             10.843373
# 697                              0.000000
# 698                             36.655832
# 699                             42.734657
#
#      % FirstGenStudents Withdrawn 3 Years  \
# 0                               31.392778
# 1                               23.980278
# 2                                0.000000
# 3                               23.721436
# 4                               38.818974
# ..                                    ...
# 695                             59.589041
# 696                              0.000000
# 697                              0.000000
# 698                             32.972771
# 699                             43.251121
#
#      % FirstGenStudents Withdrawn 4 Years  \
# 0                               35.079365
# 1                               21.829856
# 2                                0.000000
# 3                               27.923628
# 4                               33.168317
# ..                                    ...
# 695                             57.865169
# 696                             12.446352
# 697                              0.000000
# 698                             33.888320
# 699                             42.368932
#
#      % FirstGenStudents Withdrawn 6 Years  \
# 0                               33.170732
# 1                               18.627451
# 2                                0.000000
# 3                               19.342105
# 4                               30.930721
# ..                                    ...
# 695                              0.000000
# 696                             13.147410
# 697                              0.000000
# 698                             25.938804
# 699                             41.766110
#
#      % FirstGenStudents Withdrawn 8 Years        id   Latitude  Longitutde
# 0                               27.157652  10065400  3478.3368  -8656.8502
# 1                               16.675839  10066300  3350.5697  -8679.9345
# 2                                0.000000  10069000  3236.2609  -8617.4010
# 3                               15.914787  10070600  3472.4557  -8664.0449
# 4                               27.492447  10072400  3236.4317  -8629.5677
# ..                                    ...       ...        ...         ...
# 695                              0.000000  13682600  2559.9247  -8039.0054
# 696                             10.526316  13695000  2859.2787  -8134.9239
# 697                              0.000000  13702300  2992.4377  -8134.5829
# 698                             20.958084  13703200  2833.6776  -8225.7801
# 699                             34.963852  13707800  2790.2420  -8271.7331
#
# [700 rows x 64 columns]

# %%
dependency_clean.columns
# Out:
# Index(['School Name', '% IndepStudents, LowIncome $0-$30,000',
#        '% Independent Students', '% DepStudents, LowIncome $0-$30,000',
#        '% aided students family income $0-$30,000',
#        '% First Generation Students', '% First Gen, Parents w/College',
#        '% First Gen, Parents w/MiddleSchool',
#        '% First Gen, Parents w/HighSchool',
#        '% FirstGenStudents, Completed 2 Years',
#        '% FirstGenStudents, Completed 3 Years',
#        '% FirstGenStudents, Completed 4 Years',
#        '% FirstGenStudents, Completed 6 Years',
#        '% FirstGenStudents, Completed 8 Years',
#        '% Students W/Bachelors Degree at 25 Years Old',
#        '% Students Born Within the U.S.',
#        '% Population of White Students by ZIP Code',
#        '% Population of Hispanic Students by ZIP Code',
#        '% Population of Black Students by ZIP Code',
#        '% Population of Asian Students by ZIP Code',
#        '% Students W/Professional Deg at 25YrsbyZIP',
#        '% IndepStudents Completed 2 Years',
#        '% IndepStudents Completed 3 Years',
#        '% IndepStudents Completed 4 Years',
#        '% IndepStudents Completed 6 Years',
#        '% IndepStudents Completed 8 Years',
#        '% IndepStudents Withdrawn 2 Years',
#        '% IndepStudents Withdrawn 3 Years',
#        '% IndepStudents Withdrawn 4 Years',
#        '% IndepStudents Withdrawn 6 Years',
#        '% IndepStudents Withdrawn 8 Years', '% DepStudents Completed 2 Years',
#        '% DepStudents Completed 3 Years', '% DepStudents Completed 4 Years',
#        '% DepStudents Completed 6 Years', '% DepStudents Completed 8 Years',
#        '% DepStudents Withdrawn 2 Years', '% DepStudents Withdrawn 3 Years',
#        '% DepStudents, Withdrawn 4 Years', '% DepStudents, Withdrawn 6 Years',
#        '% DepStudents, Withdrawn 8 Years',
#        '% NonFirstGenStudents Completed 2 Years',
#        '% NonFirstGenStudents Completed 3 Years',
#        '% NonFirstGenStudents Completed 4 Years',
#        '% NonFirstGenStudents Completed 6 Years',
#        '% NonFirstGenStudents Completed 8 Years',
#        '% NonFirstGenStudents Withdrawn 2 Years',
#        '% NonFirstGenStudents Withdrawn 3 Years',
#        '% NonFirstGenStudents Withdrawn 4 Years',
#        '% NonFirstGenStudents Withdrawn 6 Years',
#        '% NonFirstGenStudents Withdrawn 8 Years',
#        '% FirstGenStudents Completed 2 Years',
#        '% FirstGenStudents Completed 3 Years',
#        '% FirstGenStudents Completed 4 Years',
#        '% FirstGenStudents Completed 6 Years',
#        '% FirstGenStudents Completed 8 Years',
#        '% FirstGenStudents Withdrawn 2 Years',
#        '% FirstGenStudents Withdrawn 3 Years',
#        '% FirstGenStudents Withdrawn 4 Years',
#        '% FirstGenStudents Withdrawn 6 Years',
#        '% FirstGenStudents Withdrawn 8 Years', 'id', 'Latitude', 'Longitutde'],
#       dtype='object')

# %%
#dependency_clean = dependency_clean.drop_duplicates(subset='School Name')
#dependency_clean = dependency_clean.set_index('School Name')
#dependency_clean.to_json('dependency_clean.json' , orient = 'index', compression = 'infer' , index = 'true')
#dependency_clean.to_csv('CSVs/dependency_clean.csv')

# %%
dependency_clean.columns
# Out:
# Index(['% Independent Students, Low Income Between $0-$30,000',
#        '% Independent Students',
#        '% Dependent Students, Low Income Between $0-$30,000',
#        '% aided students whose family income is between $0-$30,000',
#        '% First Generation Students',
#        '% First Generation Students, Parents With Some College',
#        '% First Generation Students, Parents With Middle School Education',
#        '% First Generation Students, Parents With High School Education',
#        '% First Generation Students, Transferred and Completed Within 2 Years',
#        '% First Generation Students, Transferred and Completed Within 3 Years',
#        '% First Generation Students, Transferred and Completed Within 4 Years',
#        '% First Generation Students, Transferred and Completed Within 6 Years',
#        '% First Generation Students, Transferred and Completed Within 8 Years',
#        '% Students With a Bachelors Degree at 25 Years Old',
#        '% Students Born Within the U.S.',
#        '% Population of White Students by ZIP Code',
#        '% Population of Hispanic Students by ZIP Code',
#        '% Population of Black Students by ZIP Code',
#        '% Population of Asian Students by ZIP Code',
#        '% Population of Students With a Professional Degre at 25 Years Old by ZIP Code',
#        '% Independent Students, Completed Within 2 Years',
#        '% Independent Students, Completed by 3 Years',
#        '% Independent Students, Completed Within 4 Years',
#        '% Independent Students, Completed Within 6 Years',
#        '% Independent Students, Completed Within 8 Years',
#        '% Independent Students, Withdrawn Within 2 Years',
#        '% Independent Students, Withdrawn Within 3 Years',
#        '% Independent Students, Withdrawn Within 4 Years',
#        '% Independent Students, Withdrawn Within 6 Years',
#        '% Independent Students, Withdrawn Within 8 Years',
#        '% Dependent Students, Completed Within 2 Years',
#        '% Dependent Students, Completed Within 3 Years',
#        '% Dependent Students, Completed Within 4 Years',
#        '% Dependent Students, Completed Within 6 Years',
#        '% Dependent Students, Completed Within 8 Years',
#        '% Dependent Students, Withdrawn Within 2 Years',
#        '% Dependent Students, Withdrawn Within 3 Years',
#        '% Dependent Students, Withdrawn Within 4 Years',
#        '% Dependent Students, Withdrawn Within 6 Years',
#        '% Dependent Students, Withdrawn Within 8 Years',
#        '% Non First Generation Students, Completed Within 2 Years',
#        '% Non First Generation Students, Completed Within 3 Years',
#        '% Non First Generation Students, Completed Within 4 Years',
#        '% Non First Generation Students, Completed Within 6 Years',
#        '% Non First Generation Students, Completed Within 8 Years',
#        '% Non First Generation Students, Withdrawn Within 2 Years',
#        '% Non First Generation Students, Withdrawn Within 3 Years',
#        '% Non First Generation Students, Withdrawn Within 4 Years',
#        '% Non First Generation Students, Withdrawn Within 6 Years',
#        '% Non First Generation Students, Withdrawn Within 8 Years',
#        '% First Generation Students, Completed Within 2 Years',
#        '% First Generation Students, Completed Within 3 Years',
#        '% First Generation Students, Completed Within 4 Years',
#        '% First Generation Students, Completed Within 6 Years',
#        '% First Generation Students, Completed Within 8 Years',
#        '% First Generation Students, Withdrawn by 2 Years',
#        '% First Generation Students, Withdrawn by 3 Years',
#        '% First Generation Students, Withdrawn by 4 Years',
#        '% First Generation Students, Withdrawn by 6 Years',
#        '% First Generation Students, Withdrawn by 8 Years', 'id', 'Latitude',
#        'Longitutde'],
#       dtype='object')

# %%
dependency_clean
# Out:
#                                                     % Independent Students, Low Income Between $0-$30,000  \
# School Name
# Alabama A & M University                                                                    90.158730
# University of Alabama at Birmingham                                                         59.420290
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         68.885191
# Alabama State University                                                                    92.193309
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          88.953488
# Rollins College                                                                             64.779874
# First Coast Technical College                                                               84.879725
# Saint Leo University                                                                        67.374980
# St Petersburg College                                                                       71.350658
#
#                                                     % Independent Students  \
# School Name
# Alabama A & M University                                          9.887006
# University of Alabama at Birmingham                              32.140861
# Amridge University                                               89.527027
# University of Alabama in Huntsville                              25.156969
# Alabama State University                                         10.742812
# ...                                                                    ...
# Robert Morgan Educational Center and Technical ...               46.361186
# Rollins College                                                  19.875000
# First Coast Technical College                                    67.674419
# Saint Leo University                                             78.868448
# St Petersburg College                                            54.236993
#
#                                                     % Dependent Students, Low Income Between $0-$30,000  \
# School Name
# Alabama A & M University                                                                    56.913967
# University of Alabama at Birmingham                                                         34.870950
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         26.901566
# Alabama State University                                                                    57.762864
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          63.316583
# Rollins College                                                                             28.705148
# First Coast Technical College                                                               64.748201
# Saint Leo University                                                                        43.530113
# St Petersburg College                                                                       49.087452
#
#                                                     % aided students whose family income is between $0-$30,000  \
# School Name
# Alabama A & M University                                                                    60.200879
# University of Alabama at Birmingham                                                         42.761319
# Amridge University                                                                          77.364865
# University of Alabama in Huntsville                                                         37.463374
# Alabama State University                                                                    61.461661
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          75.202156
# Rollins College                                                                             35.875000
# First Coast Technical College                                                               78.372093
# Saint Leo University                                                                        62.336190
# St Petersburg College                                                                       61.162346
#
#                                                     % First Generation Students  \
# School Name
# Alabama A & M University                                              36.582809
# University of Alabama at Birmingham                                   34.122367
# Amridge University                                                    51.250000
# University of Alabama in Huntsville                                   31.013216
# Alabama State University                                              34.343434
# ...                                                                         ...
# Robert Morgan Educational Center and Technical ...                    51.557093
# Rollins College                                                       23.753281
# First Coast Technical College                                         50.546448
# Saint Leo University                                                  49.104320
# St Petersburg College                                                 44.426396
#
#                                                     % First Generation Students, Parents With Some College  \
# School Name
# Alabama A & M University                                                                    63.417191
# University of Alabama at Birmingham                                                         65.877633
# Amridge University                                                                          48.750000
# University of Alabama in Huntsville                                                         68.986784
# Alabama State University                                                                    65.656566
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          48.442907
# Rollins College                                                                             76.246719
# First Coast Technical College                                                               49.453552
# Saint Leo University                                                                        50.895680
# St Petersburg College                                                                       55.573604
#
#                                                     % First Generation Students, Parents With Middle School Education  \
# School Name
# Alabama A & M University                                                                     1.642208
# University of Alabama at Birmingham                                                          2.226680
# Amridge University                                                                           5.000000
# University of Alabama in Huntsville                                                          1.982379
# Alabama State University                                                                     1.882461
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                           5.190311
# Rollins College                                                                              0.000000
# First Coast Technical College                                                                5.191257
# Saint Leo University                                                                         4.350444
# St Petersburg College                                                                        3.644670
#
#                                                     % First Generation Students, Parents With High School Education  \
# School Name
# Alabama A & M University                                                                    34.940601
# University of Alabama at Birmingham                                                         31.895687
# Amridge University                                                                          46.250000
# University of Alabama in Huntsville                                                         29.030837
# Alabama State University                                                                    32.460973
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          46.366782
# Rollins College                                                                              0.000000
# First Coast Technical College                                                               45.355191
# Saint Leo University                                                                        44.753876
# St Petersburg College                                                                       40.781726
#
#                                                     % First Generation Students, Transferred and Completed Within 2 Years  \
# School Name
# Alabama A & M University                                                                     0.000000
# University of Alabama at Birmingham                                                          3.251318
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                          0.000000
# Alabama State University                                                                     0.000000
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                           0.000000
# Rollins College                                                                              0.000000
# First Coast Technical College                                                                0.000000
# Saint Leo University                                                                         0.000000
# St Petersburg College                                                                        1.669675
#
#                                                     % First Generation Students, Transferred and Completed Within 3 Years  \
# School Name
# Alabama A & M University                                                                     0.000000
# University of Alabama at Birmingham                                                          4.303003
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                          3.046790
# Alabama State University                                                                     0.000000
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                           0.000000
# Rollins College                                                                              0.000000
# First Coast Technical College                                                                0.000000
# Saint Leo University                                                                         3.207758
# St Petersburg College                                                                        2.040359
#
#                                                     ...  \
# School Name                                         ...
# Alabama A & M University                            ...
# University of Alabama at Birmingham                 ...
# Amridge University                                  ...
# University of Alabama in Huntsville                 ...
# Alabama State University                            ...
# ...                                                 ...
# Robert Morgan Educational Center and Technical ...  ...
# Rollins College                                     ...
# First Coast Technical College                       ...
# Saint Leo University                                ...
# St Petersburg College                               ...
#
#                                                     % First Generation Students, Completed Within 6 Years  \
# School Name
# Alabama A & M University                                                                    29.463415
# University of Alabama at Birmingham                                                         51.470588
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         45.394737
# Alabama State University                                                                    30.160952
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          27.586207
# Rollins College                                                                             67.729084
# First Coast Technical College                                                               54.752852
# Saint Leo University                                                                        36.671303
# St Petersburg College                                                                       27.599727
#
#                                                     % First Generation Students, Completed Within 8 Years  \
# School Name
# Alabama A & M University                                                                    28.538550
# University of Alabama at Birmingham                                                         51.953770
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         46.867168
# Alabama State University                                                                    26.888218
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          29.597701
# Rollins College                                                                             65.460526
# First Coast Technical College                                                               44.705882
# Saint Leo University                                                                        41.816367
# St Petersburg College                                                                       25.872943
#
#                                                     % First Generation Students, Withdrawn by 2 Years  \
# School Name
# Alabama A & M University                                                                    35.826772
# University of Alabama at Birmingham                                                         21.485062
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         23.888314
# Alabama State University                                                                    34.318182
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          44.805195
# Rollins College                                                                             10.843373
# First Coast Technical College                                                                0.000000
# Saint Leo University                                                                        36.655832
# St Petersburg College                                                                       42.734657
#
#                                                     % First Generation Students, Withdrawn by 3 Years  \
# School Name
# Alabama A & M University                                                                    31.392778
# University of Alabama at Birmingham                                                         23.980278
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         23.721436
# Alabama State University                                                                    38.818974
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          59.589041
# Rollins College                                                                              0.000000
# First Coast Technical College                                                                0.000000
# Saint Leo University                                                                        32.972771
# St Petersburg College                                                                       43.251121
#
#                                                     % First Generation Students, Withdrawn by 4 Years  \
# School Name
# Alabama A & M University                                                                    35.079365
# University of Alabama at Birmingham                                                         21.829856
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         27.923628
# Alabama State University                                                                    33.168317
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                          57.865169
# Rollins College                                                                             12.446352
# First Coast Technical College                                                                0.000000
# Saint Leo University                                                                        33.888320
# St Petersburg College                                                                       42.368932
#
#                                                     % First Generation Students, Withdrawn by 6 Years  \
# School Name
# Alabama A & M University                                                                    33.170732
# University of Alabama at Birmingham                                                         18.627451
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         19.342105
# Alabama State University                                                                    30.930721
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                           0.000000
# Rollins College                                                                             13.147410
# First Coast Technical College                                                                0.000000
# Saint Leo University                                                                        25.938804
# St Petersburg College                                                                       41.766110
#
#                                                     % First Generation Students, Withdrawn by 8 Years  \
# School Name
# Alabama A & M University                                                                    27.157652
# University of Alabama at Birmingham                                                         16.675839
# Amridge University                                                                           0.000000
# University of Alabama in Huntsville                                                         15.914787
# Alabama State University                                                                    27.492447
# ...                                                                                               ...
# Robert Morgan Educational Center and Technical ...                                           0.000000
# Rollins College                                                                             10.526316
# First Coast Technical College                                                                0.000000
# Saint Leo University                                                                        20.958084
# St Petersburg College                                                                       34.963852
#
#                                                           id   Latitude  \
# School Name
# Alabama A & M University                            10065400  3478.3368
# University of Alabama at Birmingham                 10066300  3350.5697
# Amridge University                                  10069000  3236.2609
# University of Alabama in Huntsville                 10070600  3472.4557
# Alabama State University                            10072400  3236.4317
# ...                                                      ...        ...
# Robert Morgan Educational Center and Technical ...  13682600  2559.9247
# Rollins College                                     13695000  2859.2787
# First Coast Technical College                       13702300  2992.4377
# Saint Leo University                                13703200  2833.6776
# St Petersburg College                               13707800  2790.2420
#
#                                                     Longitutde
# School Name
# Alabama A & M University                            -8656.8502
# University of Alabama at Birmingham                 -8679.9345
# Amridge University                                  -8617.4010
# University of Alabama in Huntsville                 -8664.0449
# Alabama State University                            -8629.5677
# ...                                                        ...
# Robert Morgan Educational Center and Technical ...  -8039.0054
# Rollins College                                     -8134.9239
# First Coast Technical College                       -8134.5829
# Saint Leo University                                -8225.7801
# St Petersburg College                               -8271.7331
#
# [697 rows x 63 columns]
